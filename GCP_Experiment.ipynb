# %%
import numpy as np
import rasterio # must be version >1. (using 1.09)
import pandas as pd
import matplotlib.pyplot as plt
import os as os
# %matplotlib inline

# %%
# bilinear interpolation
def bilint(z,en):
    """
    https://en.wikipedia.org/wiki/Bilinear_interpolation for a unit square
    """
    r = en[1]
    c = en[0]
    ir = np.int(r)
    ic = np.int(c)
    rx = r-ir
    cy = c-ic
    #print(r,ir,rx,'  ',c,ic,cy)
    #print(z[ir,ic],z[ir+1,ic])
    #print(z[ir+1,ic],z[ir+1,ic+1])
    zi = z[ir,ic]*(1.-cy)*(1.-rx)+z[ir+1,ic]*cy*(1.-rx)+z[ir,ic+1]*(1.-cy)*rx+z[ir+1,ic+1]*rx*cy
    return zi

# %%
# all of these are 10cm DEMS
indir =  "D:\\crs\proj\\2015_Sandwich\\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\\2017-01-25_products\\"
outdir = indir+"gcpx_results\\"

for i in range(6):
    dname = 'case{0:d}'.format(i+1) +'.tif'
    tname = '2017-01-25_trans.txt'
    print(indir+dname)
    print(indir+tname)
    try:
        f=open(indir+tname,'r')
    except OSError:
        print(tname+" is missing.")
    else:
        print(tname," has ",len(f.readlines()),"lines.")
        
    # read in the transect points
    column_names = ['e','n','elev']
    df=pd.read_csv(indir+tname, header = None, names=column_names, delimiter=',')
    print("Read: ",len(df.index),' lines.')
    
    # read DEM channel 1
    print("Reading "+indir+dname+"...")
    with rasterio.open(indir+dname) as dem:
        z = dem.read(1)
        z[z <= -99]=np.nan
    print("DEM shape: ",np.shape(z))
    
    # The transform uses rasterio 
    print("rasterio gdal version: ",rasterio.gdal_version())
    # coordinate reference system
    print(dem.crs)
    # data transform
    print(dem.transform)
    # upper left corner
    print('upper left: ',dem.transform*(0,0))
    # lower right corner
    print('lower right: ',dem.transform*(dem.width, dem.height))
    
    # arrays for DEM and differences calcs
    zdem = np.NaN*np.ones(len(df.index))
    zdem_minus_meas = np.NaN*np.ones(len(df.index))
    
    for index, row in df.iterrows():
        en = ~dem.transform*(row["e"],row["n"])
        #print( index, en )

        # bilinear interpolation in DEM
        try:
            zdem[index]=bilint(z,en)
        except:
            print("interpolation problem")

        # No data values for DEM are -32767
        if(zdem[index]<-32000.):
            zdem[index]=np.NaN           

        zdem_minus_meas[index] = zdem[index]-row["elev"]
        #print( zdem[index], zdi[index], row["elev"], zdem_minus_meas[index]  )

    # add columns to the dataframe
    #df.assign(DEM2=pd.Series(zdem,index=df.index))
    df['DEM (interp, m)']=pd.Series(zdem,index=df.index)
    df['DEM_minus_trans (m)']=pd.Series(zdem_minus_meas,index=df.index)
        
    print("\nStatistics for interpolated values:")
    print(df['DEM_minus_trans (m)'].describe())
    
    print("\nSaving to "+outdir+"case{0:d}".format(i+1)+"_diff.txt")
    df.to_csv(outdir+"case{0:d}".format(i+1)+'_diff.txt',na_rep='nan',sep=',',float_format='% 12.4f')
    
    ## Histogram of the data
    dz = df['DEM_minus_trans (m)'].as_matrix()
    dz = dz[~np.isnan(dz)]
    #dz = dz[np.abs(dz)<5.]

    dzN = len(dz)
    dzMAD = np.mean(np.abs(dz))
    dzmean = dz.mean()
    dzmin = dz.min()
    dzmax = dz.max()
    dzRMS = np.sqrt(np.mean(dz**2))

    fig = plt.figure()
    # next line must be combined with normed=False to get fractional distribution correct
    weights = np.ones_like(dz)/float(len(dz))
    n, bins, patches = plt.hist(dz, bins=40, weights=weights, normed=False, facecolor=(.2,.2,.2), alpha=1)
    xaxmax = 1
    xaxmin = -1
    yaxmin = 0.
    yaxmax = .45
    
    plt.xlabel('DEM minus Survey Point (m)')
    plt.ylabel('Fraction of Observations')
    plt.title('Case {0:d}'.format(i+1))
    plt.axis([xaxmin, xaxmax, yaxmin, yaxmax])
    plt.grid(True)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.9*(yaxmax-yaxmin)+yaxmin,'N = {}'.format(dzN), fontsize=11)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.85*(yaxmax-yaxmin)+yaxmin,'Mean = {:.3f}'.format(dzmean), fontsize=11)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.8*(yaxmax-yaxmin)+yaxmin,'RMS = {:.3f}'.format(dzRMS), fontsize=11)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.75*(yaxmax-yaxmin)+yaxmin,'MAD = {:.3f}'.format(dzMAD), fontsize=11)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.7 *(yaxmax-yaxmin)+yaxmin,'Min = {:.3f}'.format(dzmin), fontsize=11)
    plt.text(.75*(xaxmax-xaxmin)+xaxmin,.65*(yaxmax-yaxmin)+yaxmin,'Max = {:.3f}'.format(dzmax), fontsize=11)
    plt.show()

    fig_name = outdir+"case{0:d}".format(i+1)+"_DEM_minus_transect_HIST.png"
    fig.savefig(fig_name)
    
    # make map of differences
    dz = df['DEM_minus_trans (m)'].as_matrix()
    x = df['e'].as_matrix()
    y = df['n'].as_matrix()
    fig2 = plt.figure()
    plt.plot(figsize=(12,6))
    #plt.imshow(z[::],cmap=plt.cm.gray,vmin=-2,vmax=13)
    plt.scatter(x,y,8,dz,vmin=-.2,vmax=.2)
    fig_name = outdir+"case{0:d}".format(i+1)+"_DEM_minus_transect_MAP.png"
    plt.show()
    fig2.savefig(fig_name)
# Out:
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case1.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case1.tif...
# DEM shape:  (16480, 18880)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375907.00|
# | 0.00,-0.10, 4625694.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375907.0, 4625694.0)
# lower right:  (377795.0, 4624046.0)
#
# Statistics for interpolated values:
# count    145.000000
# mean     111.338786
# std        3.138573
# min      107.617203
# 25%      109.490394
# 50%      110.467929
# 75%      112.361928
# max      125.068169
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case1_diff.txt
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case2.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case2.tif...
# DEM shape:  (16490, 18850)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375911.00|
# | 0.00,-0.10, 4625694.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375911.0, 4625694.0)
# lower right:  (377796.0, 4624045.0)
#
# Statistics for interpolated values:
# count    147.000000
# mean       1.273257
# std        1.057230
# min       -0.265674
# 25%        0.424179
# 50%        0.975542
# 75%        2.039771
# max        4.116079
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case2_diff.txt
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case3.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case3.tif...
# DEM shape:  (16500, 18830)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375912.00|
# | 0.00,-0.10, 4625694.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375912.0, 4625694.0)
# lower right:  (377795.0, 4624044.0)
#
# Statistics for interpolated values:
# count    150.000000
# mean      11.160594
# std       11.138470
# min       -2.989042
# 25%        2.093898
# 50%       10.201731
# 75%       17.824592
# max       40.007336
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case3_diff.txt
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case4.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case4.tif...
# DEM shape:  (16440, 18810)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375913.00|
# | 0.00,-0.10, 4625691.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375913.0, 4625691.0)
# lower right:  (377794.0, 4624047.0)
#
# Statistics for interpolated values:
# count    150.000000
# mean       0.046938
# std        0.209489
# min       -0.494969
# 25%       -0.138094
# 50%        0.039808
# 75%        0.204916
# max        0.697736
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case4_diff.txt
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case5.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case5.tif...
# DEM shape:  (16450, 18810)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375913.00|
# | 0.00,-0.10, 4625692.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375913.0, 4625692.0)
# lower right:  (377794.0, 4624047.0)
#
# Statistics for interpolated values:
# count    149.000000
# mean      -0.095094
# std        0.226826
# min       -0.620991
# 25%       -0.295069
# 50%       -0.068710
# 75%        0.079230
# max        0.443483
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case5_diff.txt
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case6.tif
# D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\2017-01-25_trans.txt
# 2017-01-25_trans.txt  has  152 lines.
# Read:  152  lines.
# Reading D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\case6.tif...
# DEM shape:  (16400, 18780)
# rasterio gdal version:  2.2.0
# CRS({'init': 'epsg:26919'})
# | 0.10, 0.00, 375915.00|
# | 0.00,-0.10, 4625689.00|
# | 0.00, 0.00, 1.00|
# upper left:  (375915.0, 4625689.0)
# lower right:  (377793.0, 4624049.0)
#
# Statistics for interpolated values:
# count    150.000000
# mean       0.026811
# std        0.078698
# min       -0.192416
# 25%       -0.035346
# 50%        0.017565
# 75%        0.066815
# max        0.259086
# Name: DEM_minus_trans (m), dtype: float64
#
# Saving to D:\crs\proj\2015_Sandwich\2017-01-25_U021_SandwichTNB_UAS_Survey_and_RBR_recovery\2017-01-25_products\gcpx_results\case6_diff.txt
